# %% [markdown]
# # 📊 Exploratory Data Analysis
# Generated automatically by `envy`.

# %%
import polars as pl

# Load dataset
df = pl.read_csv("data/raw/dataset.csv")

print(f"Shape: {df.shape}")
df.head()
